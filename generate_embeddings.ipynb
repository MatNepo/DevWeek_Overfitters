# %% [markdown]
# Установка и импорт библиотек для семантического поиска: `sentence-transformers` — для получения текстовых эмбеддингов с помощью предобученных моделей, `faiss-cpu` — для эффективного поиска по эмбеддингам, `numpy` — для работы с массивами, `json` — для загрузки/сохранения структурированных данных.

# %%
# !pip install -q sentence-transformers faiss-cpu

from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
import json
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 55.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.5 MB/s eta 0:00:00

# %% [markdown]
# Установка необходимых библиотек в среде Google Colab: `sentence-transformers` для работы с эмбеддингами текста и `faiss-cpu` для реализации быстрого поиска ближайших соседей по эмбеддингам.

# %%
# !pip install -q sentence-transformers faiss-cpu

# %% [markdown]
# ##Код для создания эмбендингов

# %% [markdown]
# Определение путей к файлам: `json_path` — путь к входному JSON-файлу с видео и хэштегами, `out_emb_path` — путь для сохранения массива эмбеддингов, `out_meta_path` — путь для сохранения сопутствующей метаинформации (например, имён файлов).

# %%
json_path = '/content/merged_with_tags_0_3600.json'
out_emb_path = '/content/embeddings.npy'
out_meta_path = '/content/metadata.json'

# %% [markdown]
# Загрузка модели `SentenceTransformer` для получения эмбеддингов текста.
# Чтение входного JSON-файла и генерация эмбеддингов для каждого непустого поля `description` и `transcription`.
# Для каждого эмбеддинга сохраняется соответствующая метаинформация (id, имя файла, тип поля).
# Эмбеддинги сохраняются в `.npy`-файл, а метаданные — в `.json`.
# Выводится статистика по обработанным и пропущенным записям.

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import json
from tqdm import tqdm

# Загружаем модель
model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')


# Загружаем JSON
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

vectors = []
meta = []

processed = 0
skipped = 0

print(f'🔄 Обработка {len(data)} записей...')

for item in tqdm(data):
    item_id = item.get("id")
    filename = item.get("filename")

    for field in ['description', 'transcription']:
        text = item.get(field)
        if text:
            emb = model.encode(text)
            vectors.append(emb)
            meta.append({
                'id': item_id,
                'filename': filename,
                'field': field
            })
            processed += 1
        else:
            skipped += 1

# Преобразуем в numpy-массив
vectors = np.vstack(vectors)

# Сохраняем
np.save(out_emb_path, vectors)
with open(out_meta_path, 'w', encoding='utf-8') as f:
    json.dump(meta, f, ensure_ascii=False, indent=2)

print('\n✅ Готово!')
print(f'✔️ Эмбендингов сохранено: {processed}')
print(f'⚠️ Пропущено пустых полей: {skipped}')
print(f'📁 Массив сохранён в: {out_emb_path}')
print(f'📄 Метаданные сохранены в: {out_meta_path}')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 🔄 Обработка 3581 записей...
# 100%|██████████| 3581/3581 [13:36<00:00,  4.39it/s]
# ✅ Готово!
# ✔️ Эмбендингов сохранено: 7162
# ⚠️ Пропущено пустых полей: 0
# 📁 Массив сохранён в: /content/embeddings.npy
# 📄 Метаданные сохранены в: /content/metadata.json

# %% [markdown]
# ## Поиск

# %% [markdown]
# Импорт необходимых библиотек: `numpy` для работы с массивами, `json` для загрузки и сохранения данных, `faiss` для быстрого поиска по эмбеддингам,
# `defaultdict` из модуля `collections` для удобного создания словарей со значениями по умолчанию, и `SentenceTransformer` для преобразования текста в эмбеддинги.

# %%
import numpy as np
import json
import faiss
from collections import defaultdict
from sentence_transformers import SentenceTransformer

# %% [markdown]
# Определение функций для загрузки данных, нормализации векторов, построения FAISS-индекса и выполнения различных стратегий поиска по эмбеддингам.
#
# - `load_data(...)` — загружает эмбеддинги, метаданные и исходные JSON-данные.
# - `normalize_vectors(...)` — нормализует эмбеддинги по L2-норме.
# - `build_faiss_index(...)` — создает FAISS-индекс для поиска по косинусной близости.
# - `search_description(...)` — ищет топ-k наиболее подходящих видео по эмбеддингам описаний.
# - `search_combined(...)` — объединяет эмбеддинги описания и транскрипции для поиска.
# - `search_transcription(...)` — ищет по эмбеддингам транскрипций.
# - `search_combined_scores(...)` — объединяет результаты поиска по описанию и транскрипции, применяет порог фильтрации и возвращает отсортированный список наиболее релевантных видео.

# %%
def load_data(embeddings_path, metadata_path, source_json_path):
    vectors = np.load(embeddings_path)
    with open(metadata_path, 'r', encoding='utf-8') as f:
        meta = json.load(f)
    with open(source_json_path, 'r', encoding='utf-8') as f:
        source_data = json.load(f)
    return vectors, meta, source_data

def normalize_vectors(vectors):
    return vectors / np.linalg.norm(vectors, axis=1, keepdims=True)

def build_faiss_index(vectors):
    dim = vectors.shape[1]
    index = faiss.IndexFlatIP(dim)
    index.add(vectors)
    return index

def search_description(query_vector, vecs_norm, meta, source_by_filename, top_k=10):
    desc_idxs = [i for i, m in enumerate(meta) if m['field'] == 'description']
    desc_vectors = vecs_norm[desc_idxs]
    index = build_faiss_index(desc_vectors)
    scores, top_ids = index.search(query_vector, top_k)
    results = []
    for score, idx in zip(scores[0], top_ids[0]):
        real_idx = desc_idxs[idx]
        m = meta[real_idx]
        description = source_by_filename[m['filename']].get('description', '[нет description]')
        results.append({
            'score': float(score),
            'id': m['id'],
            'filename': m['filename'],
            'description': description
        })
    return results

def search_combined(query_vector, vecs_norm, meta, source_by_filename, top_k=10):
    grouped = defaultdict(dict)
    for i, m in enumerate(meta):
        grouped[m['filename']][m['field']] = i

    combined_vectors = []
    combined_meta = []

    for filename, fields in grouped.items():
        if 'description' in fields and 'transcription' in fields:
            i1 = fields['description']
            i2 = fields['transcription']
            combined = vecs_norm[i1] + vecs_norm[i2]
            combined /= np.linalg.norm(combined)
            combined_vectors.append(combined)
            combined_meta.append({
                'filename': filename,
                'id': meta[i1]['id']
            })

    combined_vectors = np.vstack(combined_vectors)
    index = build_faiss_index(combined_vectors)
    scores, top_ids = index.search(query_vector, top_k)

    results = []
    for score, idx in zip(scores[0], top_ids[0]):
        m = combined_meta[idx]
        description = source_by_filename[m['filename']].get('description', '[нет description]')
        results.append({
            'score': float(score),
            'id': m['id'],
            'filename': m['filename'],
            'description': description
        })
    return results

def search_transcription(query_vector, vecs_norm, meta, source_by_filename, top_k=10):
    trans_idxs = [i for i, m in enumerate(meta) if m['field'] == 'transcription']
    trans_vectors = vecs_norm[trans_idxs]
    index = build_faiss_index(trans_vectors)
    scores, top_ids = index.search(query_vector, top_k)
    results = []
    for score, idx in zip(scores[0], top_ids[0]):
        real_idx = trans_idxs[idx]
        m = meta[real_idx]
        description = source_by_filename[m['filename']].get('description', '[нет description]')
        transcription = source_by_filename[m['filename']].get('transcription', '[нет transcription]')
        results.append({
            'score': float(score),
            'id': m['id'],
            'filename': m['filename'],
            'description': description,
            'transcription': transcription
        })
    return results

def search_combined_scores(query_vector, vecs_norm, meta, source_by_filename, top_k=10, threshold=0.5):
    """
    Выполняет комбинированный поиск, вычисляя отдельные показатели для описания и транскрипции,
    суммируя их, применяя пороговое значение и возвращая топ-k результатов.

    Аргументы:
        query_vector: Вектор эмбеддинга запроса.
        vecs_norm: Нормализованные векторы эмбеддингов для всех полей видео.
        meta: Метаданные, связывающие эмбеддинги с именами файлов и полями.
        source_by_filename: Словарь, связывающий имена файлов с их метаданными (описание, id и т.д.).
        top_k: Количество возвращаемых результатов (по умолчанию: 10).
        threshold: Минимальный комбинированный показатель для включения результата (по умолчанию: 0.5).

    Возвращает:
        Список словарей с именем файла, комбинированным показателем, индивидуальными показателями,
        описанием, транскрипцией и id, отсортированный по комбинированному показателю.
    """
    # Шаг 1: Выполняем отдельные поиски для описания и транскрипции
    desc_results = search_description(query_vector, vecs_norm, meta, source_by_filename, top_k=1000)
    trans_results = search_transcription(query_vector, vecs_norm, meta, source_by_filename, top_k=1000)

    # Шаг 2: Собираем показатели для каждого видео в словарь
    video_scores = {}

    # Обрабатываем результаты описания
    for result in desc_results:
        filename = result['filename']
        video_scores[filename] = video_scores.get(filename, {})
        video_scores[filename]['description'] = result['score']

    # Обрабатываем результаты транскрипции
    for result in trans_results:
        filename = result['filename']
        video_scores[filename] = video_scores.get(filename, {})
        video_scores[filename]['transcription'] = result['score']

    # Шаг 3: Вычисляем комбинированные показатели и фильтруем по порогу
    combined_results = []
    for filename, scores in video_scores.items():
        score_desc = scores.get('description', 0)  # По умолчанию 0, если поле отсутствует
        score_trans = scores.get('transcription', 0)  # По умолчанию 0, если поле отсутствует
        score_combined = score_desc + score_trans

        if score_combined >= threshold:
            combined_results.append({
                'filename': filename,
                'score': score_combined,
                'score_description': score_desc,
                'score_transcription': score_trans,
                'description': source_by_filename[filename].get('description', '[Нет описания]'),
                'transcription': source_by_filename[filename].get('transcription', '[Нет транскрипции]'),
                'id': source_by_filename[filename]['id']
            })

    # Шаг 4: Сортируем по комбинированному показателю и возвращаем топ-k
    combined_results.sort(key=lambda x: x['score'], reverse=True)
    return combined_results[:top_k]

# %% [markdown]
# Определение путей к входным файлам: `embeddings.npy` содержит эмбеддинги текстов, `metadata.json` — метаданные по каждому эмбеддингу, `merged_with_tags_0_3600.json` — исходные данные с описаниями, транскрипциями и тегами.

# %%
# Пути
embeddings_path = '/content/embeddings.npy'
metadata_path = '/content/metadata.json'
source_json_path = '/content/merged_with_tags_0_3600.json'

# %% [markdown]
# Загрузка эмбеддингов, метаданных и исходных данных с помощью функции `load_data`.
# Создание словаря `source_by_filename` для быстрого доступа к описаниям и транскрипциям по имени файла.
# Нормализация эмбеддингов с помощью функции `normalize_vectors` для использования в поиске по косинусной близости.

# %%
from sentence_transformers import SentenceTransformer

# Загрузка данных
vectors, meta, source_data = load_data(embeddings_path, metadata_path, source_json_path)

# Карта для быстрого доступа к описанию
source_by_filename = {item['filename']: item for item in source_data}

# Нормализация векторов
vecs_norm = normalize_vectors(vectors)

# %% [markdown]
# Загрузка модели `SentenceTransformer` и получение эмбеддинга текстового запроса. Выполняются четыре типа семантического поиска:
#
# 1. `search_combined(...)` — поиск по сумме эмбеддингов описания и транскрипции.
# 2. `search_description(...)` — поиск только по эмбеддингам описания.
# 3. `search_transcription(...)` — поиск только по эмбеддингам транскрипции.
# 4. `search_combined_scores(...)` — комбинированный поиск с независимыми оценками и фильтрацией по порогу.
#
# Результаты каждого поиска выводятся с указанием ID, имени файла и фрагмента описания/транскрипции.

# %%
# Загрузка модели и получение эмбендинга запроса
model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')
query = "ЛГБТ"
query_vector = model.encode([query], normalize_embeddings=True)


print(f'ЗАПРОС {query}')



# Поиск по сумме description + transcription
comb_results = search_combined(query_vector, vecs_norm, meta, source_by_filename)
print("\n📌 Топ-10 по (description + transcription):")
for r in comb_results:
    print(f"\n🔸 {r['score']:.4f} | ID: {r['id']} | Файл: https://s3.ritm.media/hackaton-itmo/{r['filename']}\n📝 {r['description'][:250]}…")


# Поиск по description
desc_results = search_description(query_vector, vecs_norm, meta, source_by_filename)

print(f'ЗАПРОС {query}')
print("\n📌 Топ-10 по description:")
for r in desc_results:
    print(f"\n🔹 {r['score']:.4f} | ID: {r['id']} | Файл: https://s3.ritm.media/hackaton-itmo/{r['filename']}\n📝 {r['description'][:250]}…")
print(f'ЗАПРОС {query}')
# Поиск по transcription
trans_results = search_transcription(query_vector, vecs_norm, meta, source_by_filename)
print("\n📌 Топ-10 по transcription:")
for r in trans_results:
    print(f"\n🔻 {r['score']:.4f} | ID: {r['id']} | Файл: https://s3.ritm.media/hackaton-itmo/{r['filename']}\n📝{r['description'][:250]}… \n {r['transcription'][:250]}…\n📄 ")
print(f'ЗАПРОС {query}')
# Поиск по сумме score(description) + score(transcription)
comb_results_new = search_combined_scores(query_vector, vecs_norm, meta, source_by_filename, top_k=10, threshold=0.6)
print("\n📌 Топ-10 по (score(description) + score(transcription)) НОВЫЙ ВАРИАНТ С ПОРОГОМ И ДРУГИМ СЛОЖЕНИЕМ:")
for r in comb_results_new:
    print(f"\n🔸 Сумма: {r['score']:.4f} | Описание: {r['score_description']:.4f} | Транскрипция: {r['score_transcription']:.4f} | ID: {r['id']} | Файл: https://s3.ritm.media/hackaton-itmo/{r['filename']}\n📝 Описание: {r['description'][:250]}…\n📜 Транскрипция: {r['transcription'][:250]}…")
# Out:
# ЗАПРОС ЛГБТ
#
# 📌 Топ-10 по (description + transcription):
#
# 🔸 0.5325 | ID: 1764 | Файл: https://s3.ritm.media/hackaton-itmo/2cc738c8-cd19-4da2-a024-f7ddc422d80e.mp4
# 📝 The video opens with a close-up of an anime-style character, specifically the upper half of their face and shoulders. The character has dark hair, is wearing glasses, and is dressed in what appears to be a school uniform consisting of a white shirt w…
#
# 🔸 0.4940 | ID: 3570 | Файл: https://s3.ritm.media/hackaton-itmo/5a11cf40-8653-4f26-ae61-6db269a80dc5.mp4
# 📝 В начале видео показаны четыре персонажа, каждый из которых находится в своей уникальной среде. Первая пара – молодой человек и девушка - находятся на улице города; они одеты стильно: он носит куртку, а она – платье. Вторая пара – мальчик с полным те…
#
# 🔸 0.4798 | ID: 2129 | Файл: https://s3.ritm.media/hackaton-itmo/366d33bd-9434-411d-8093-74935cf1d058.mp4
# 📝 The video begins with a black screen displaying white text in Russian that reads, "Все мы знаем бесконечную ульту Мортиса, но не забывайте Рико." (We all know Morty's endless ultimatum, but don't forget Rico.). The scene transitions to an animated se…
#
# 🔸 0.4692 | ID: 2012 | Файл: https://s3.ritm.media/hackaton-itmo/32bd3d9b-2729-4250-937b-2d75c55aab18.mp4
# 📝 I'm sorry, but I can't provide a description for this video as it contains content that is not appropriate to discuss.…
#
# 🔸 0.4648 | ID: 1090 | Файл: https://s3.ritm.media/hackaton-itmo/1bf245d7-e645-423d-a34a-609b4153c78f.mp4
# 📝 В начале видео, на экране отсутствует какое-либо содержимое. Затем появляются анимационные персонажи: девушки с разными цветовыми волосами и одетые в одинаковый школьныйiform. Персонажи перемещаются, их лица показывают разные эмоции.
#
# Девушка с голуб…
#
# 🔸 0.4627 | ID: 144 | Файл: https://s3.ritm.media/hackaton-itmo/03e41518-2bd9-454c-8bdc-2345e0b14c88.mp4
# 📝 The video begins with a black screen displaying white text in Russian that reads "Avatars for real Insidious dads 😈😈 Version: Evangelion". The scene transitions to an animated character with dark hair and a white shirt sitting on an orange and yellow…
#
# 🔸 0.4605 | ID: 1489 | Файл: https://s3.ritm.media/hackaton-itmo/2599e10d-16bc-4684-a310-7595d346ae8f.mp4
# 📝 The video starts with a close-up shot of an animated character with bright orange hair and pointed ears, reminiscent of fantasy or anime styles. The background is dimly lit, creating a mysterious atmosphere. Subtitles in Russian appear on the screen,…
#
# 🔸 0.4596 | ID: 1085 | Файл: https://s3.ritm.media/hackaton-itmo/1bc83532-22e6-4fc1-b628-03ed172c39e6.mp4
# 📝 В начале видео, на экране отображается текст: "Лучшие аниме для просмотра со своей парой" (Best anime to watch with your partner) с эмоджи в виде пары. Это предложение акцентирует внимание на совместном просмотре аниме.
#
# Далее, кадр раскрывает лицо п…
#
# 🔸 0.4570 | ID: 2875 | Файл: https://s3.ritm.media/hackaton-itmo/4901fc43-8370-4b6e-a09d-25c847d26a30.mp4
# 📝 The video begins with a title screen featuring the text "Аниматроники против скибиди вселенной часть 3" (Animatronics vs. Skibidi Universe Part 3). The scene transitions to an animated setting where two animatronic characters are present: one resembl…
#
# 🔸 0.4529 | ID: 865 | Файл: https://s3.ritm.media/hackaton-itmo/15f70c84-17cf-440f-a45a-4b7e2a768557.mp4
# 📝 The video begins with a black screen displaying white text in Russian. The first line reads "Подруга: послушай Алексея Воробьева, тебе понравится" (Friend: listen to Alexei Vorobyev, you'll like it). This is followed by another black screen with the …
# ЗАПРОС ЛГБТ
#
# 📌 Топ-10 по description:
#
# 🔹 0.4000 | ID: 3494 | Файл: https://s3.ritm.media/hackaton-itmo/58065b32-0d55-4010-952d-e2af8185fbc3.mp4
# 📝 The video begins with a text overlay in Russian that reads "ЛУННЫЕ ВЛЮБЛЕНИЯ ВСТРЕТИЛИСЬ В ХХI ВЕКЕ" (Lunar Love Meetings of the 21st Century). This sets the theme for the entire clip, indicating it is about love stories from the modern era. The scen…
#
# 🔹 0.3959 | ID: 3570 | Файл: https://s3.ritm.media/hackaton-itmo/5a11cf40-8653-4f26-ae61-6db269a80dc5.mp4
# 📝 В начале видео показаны четыре персонажа, каждый из которых находится в своей уникальной среде. Первая пара – молодой человек и девушка - находятся на улице города; они одеты стильно: он носит куртку, а она – платье. Вторая пара – мальчик с полным те…
#
# 🔹 0.3830 | ID: 1470 | Файл: https://s3.ritm.media/hackaton-itmo/251642e4-cf32-42c3-8fee-b6923d24c576.mp4
# 📝 The video begins with a black screen, which then transitions to an animated character dancing against a white background. The text "авы для рантов SSS+" (Avy for Rantov SSS+) appears on the screen in red letters. Following this scene is a grayscale i…
#
# 🔹 0.3811 | ID: 2681 | Файл: https://s3.ritm.media/hackaton-itmo/43d0ac09-9976-4a07-8300-a07994603529.mp4
# 📝 Описание видео: Это комедийный ролик, который начинается с группы женщин в черных нарядах, стоящих перед человеком, который пытается их разглядеть. Видимо, это часть игры или шутки, поскольку он не может видеть и должен опираться на осязание. Каждый …
#
# 🔹 0.3776 | ID: 3262 | Файл: https://s3.ritm.media/hackaton-itmo/5278f142-f771-4723-85e8-8b3babdcaaab.mp4
# 📝 В начале видео, мы видим анимационный персонажа с дредоватой прической и плечевым пучком волос, одетого в школьную форму. Он изображает различные эмоции через текстовые подсказки на экране: удивление, осознание и ужас. Затем он опускается до уровня с…
#
# 🔹 0.3739 | ID: 2357 | Файл: https://s3.ritm.media/hackaton-itmo/3ba92ab1-070e-474e-a10c-a4d40b413808.mp4
# 📝 The video begins with a close-up of an animated character's face, who has white hair and red eyes. The scene transitions to another character with black hair and blue eyes, followed by two more characters: one with silver hair and dark clothing, and …
#
# 🔹 0.3690 | ID: 265 | Файл: https://s3.ritm.media/hackaton-itmo/073984d0-4bf6-4883-9aee-39819cc76d59.mp4
# 📝 В этом видео представлено статическое изображение, которое является визуальным фоном для текста. На экране показаны две персонажи: мужчина и женщина, их лица не видны, но они смотрят друг на друга с нежностью. Персонажи находятся перед заходящим или …
#
# 🔹 0.3687 | ID: 1933 | Файл: https://s3.ritm.media/hackaton-itmo/3128c607-882f-428e-8e16-e2b8acfdf9df.mp4
# 📝 В видео, снятом на улице в холодное время года (запечатлено по одежде персонажей), два человека – один мужчина и одна женщина – общаются. Мужчина одет в темный пuffer-костюм, тёмную шапку, джинсы и солнцезащитные очки; женщина носит длинненький чёрны…
#
# 🔹 0.3683 | ID: 2063 | Файл: https://s3.ritm.media/hackaton-itmo/34a580d0-6461-44a9-b885-d3b4c69f434f.mp4
# 📝 В этом видео показаны различные персонажи, которые встречаются в разных ситуациях. На первых кадрах мы видим четырех мужчин, каждый из которых находится на своей позиции и имеет свои уникальные черты. В последующих сценах эти четыре человека встречаю…
#
# 🔹 0.3670 | ID: 2844 | Файл: https://s3.ritm.media/hackaton-itmo/4830e18a-f1a4-4963-aa06-df7158fc63c9.mp4
# 📝 Описание: Видео начинается с танцующих в паре, обнимая друг друга. Женщина имеет длинные, каскадирующиеся до плеч волосы и носит белую блazer, а мужчина — простой, но не менее элегантный, одетый в белую рубашку. Текст на экране говорит о забвении мир…
# ЗАПРОС ЛГБТ
#
# 📌 Топ-10 по transcription:
#
# 🔻 0.5419 | ID: 2372 | Файл: https://s3.ritm.media/hackaton-itmo/3c30017f-d77d-4916-89e1-c837fa37e16d.mp4
# 📝В видео представлена серия уроков по игре на гитаре, где акцент делается на обучение основам игры и практике. В кадре можно видеть бас-гuitaristа в джинсах и свитере, который демонстрирует различные ставки пальцев и техники, необходимые для выполнени…
#  ПЕСНЯ…
# 📄
#
# 🔻 0.5419 | ID: 2136 | Файл: https://s3.ritm.media/hackaton-itmo/36b89227-224f-40a5-8d10-4c615bb2bbf9.mp4
# 📝В начале видео, в темноте ночи, мы видим улицу с многоэтажными зданиями. Вокруг звучит музыка и мелькнут слова "Алиса" на экране. Затем появляется текст, который говорит о том, что нужно смотреть на красивого придура, который сломает половину жизни. …
#  ПЕСНЯ…
# 📄
#
# 🔻 0.5419 | ID: 2129 | Файл: https://s3.ritm.media/hackaton-itmo/366d33bd-9434-411d-8093-74935cf1d058.mp4
# 📝The video begins with a black screen displaying white text in Russian that reads, "Все мы знаем бесконечную ульту Мортиса, но не забывайте Рико." (We all know Morty's endless ultimatum, but don't forget Rico.). The scene transitions to an animated se…
#  ПЕСНЯ…
# 📄
#
# 🔻 0.5419 | ID: 2012 | Файл: https://s3.ritm.media/hackaton-itmo/32bd3d9b-2729-4250-937b-2d75c55aab18.mp4
# 📝I'm sorry, but I can't provide a description for this video as it contains content that is not appropriate to discuss.…
#  ПЕСНЯ…
# 📄
#
# 🔻 0.5419 | ID: 1764 | Файл: https://s3.ritm.media/hackaton-itmo/2cc738c8-cd19-4da2-a024-f7ddc422d80e.mp4
# 📝The video opens with a close-up of an anime-style character, specifically the upper half of their face and shoulders. The character has dark hair, is wearing glasses, and is dressed in what appears to be a school uniform consisting of a white shirt w…
#  ПЕСНЯ…
# 📄
#
# 🔻 0.5419 | ID: 1478 | Файл: https://s3.ritm.media/hackaton-itmo/254edc07-b13b-4890-b280-9fbe34c3a95c.mp4
# 📝В видео от начала и до конца показываются карточки с персонажами. На каждом кадре можно увидеть название персонажа, уровень и количество алмазов для его покупки.
#
# Первым появляется карточка "NEUROMANCER PAINWHEEL" с уровнем 10.9K и стоимостью в 60 ал…
#  ПЕСНЯ…
# 📄
#
# 🔻 0.5419 | ID: 441 | Файл: https://s3.ritm.media/hackaton-itmo/0ba7bf3c-f392-403e-9e8b-29c9d79e0970.mp4
# 📝[FAILED] Не удалось получить описание после 3 попыток…
#  ПЕСНЯ…
# 📄
#
# 🔻 0.5419 | ID: 95 | Файл: https://s3.ritm.media/hackaton-itmo/02a1816f-a495-4dab-88f1-07b40c34d42d.mp4
# 📝В начале видео, на экране появляется надпись: "Как отличить бивика от коровы? – Когда доишь бивика, он ехидно улыбается..." Затем на экране появляется бивик, который пожевал кусок травы, и теперь перед ним лежит куча его фекалий. В середине видео на …
#  ПЕСНЯ…
# 📄
#
# 🔻 0.4894 | ID: 865 | Файл: https://s3.ritm.media/hackaton-itmo/15f70c84-17cf-440f-a45a-4b7e2a768557.mp4
# 📝The video begins with a black screen displaying white text in Russian. The first line reads "Подруга: послушай Алексея Воробьева, тебе понравится" (Friend: listen to Alexei Vorobyev, you'll like it). This is followed by another black screen with the …
#  Занесло…
# 📄
#
# 🔻 0.4719 | ID: 92 | Файл: https://s3.ritm.media/hackaton-itmo/0296215c-0a76-449a-967f-d277efc43156.mp4
# 📝В начале видео, на экране появляется текст на русском языке: "НАСТАНЕТ ЧАС МЕЧТЫ" (время мечты придет), который остается на экране несколько секунд. Затем включается бендеровская музыка, а на экране появляются изображения различных убитых BMW-машины.…
#  и…
# 📄
# ЗАПРОС ЛГБТ
#
# 📌 Топ-10 по (score(description) + score(transcription)) НОВЫЙ ВАРИАНТ С ПОРОГОМ И ДРУГИМ СЛОЖЕНИЕМ:
#
# 🔸 Сумма: 0.8557 | Описание: 0.3138 | Транскрипция: 0.5419 | ID: 1764 | Файл: https://s3.ritm.media/hackaton-itmo/2cc738c8-cd19-4da2-a024-f7ddc422d80e.mp4
# 📝 Описание: The video opens with a close-up of an anime-style character, specifically the upper half of their face and shoulders. The character has dark hair, is wearing glasses, and is dressed in what appears to be a school uniform consisting of a white shirt w…
# 📜 Транскрипция: ПЕСНЯ…
#
# 🔸 Сумма: 0.7917 | Описание: 0.2498 | Транскрипция: 0.5419 | ID: 2129 | Файл: https://s3.ritm.media/hackaton-itmo/366d33bd-9434-411d-8093-74935cf1d058.mp4
# 📝 Описание: The video begins with a black screen displaying white text in Russian that reads, "Все мы знаем бесконечную ульту Мортиса, но не забывайте Рико." (We all know Morty's endless ultimatum, but don't forget Rico.). The scene transitions to an animated se…
# 📜 Транскрипция: ПЕСНЯ…
#
# 🔸 Сумма: 0.7622 | Описание: 0.3959 | Транскрипция: 0.3664 | ID: 3570 | Файл: https://s3.ritm.media/hackaton-itmo/5a11cf40-8653-4f26-ae61-6db269a80dc5.mp4
# 📝 Описание: В начале видео показаны четыре персонажа, каждый из которых находится в своей уникальной среде. Первая пара – молодой человек и девушка - находятся на улице города; они одеты стильно: он носит куртку, а она – платье. Вторая пара – мальчик с полным те…
# 📜 Транскрипция: Музыка…
#
# 🔸 Сумма: 0.7415 | Описание: 0.2521 | Транскрипция: 0.4894 | ID: 865 | Файл: https://s3.ritm.media/hackaton-itmo/15f70c84-17cf-440f-a45a-4b7e2a768557.mp4
# 📝 Описание: The video begins with a black screen displaying white text in Russian. The first line reads "Подруга: послушай Алексея Воробьева, тебе понравится" (Friend: listen to Alexei Vorobyev, you'll like it). This is followed by another black screen with the …
# 📜 Транскрипция: Занесло…
#
# 🔸 Сумма: 0.7294 | Описание: 0.3435 | Транскрипция: 0.3859 | ID: 1489 | Файл: https://s3.ritm.media/hackaton-itmo/2599e10d-16bc-4684-a310-7595d346ae8f.mp4
# 📝 Описание: The video starts with a close-up shot of an animated character with bright orange hair and pointed ears, reminiscent of fantasy or anime styles. The background is dimly lit, creating a mysterious atmosphere. Subtitles in Russian appear on the screen,…
# 📜 Транскрипция: ПОДПИШИСЬ!…
#
# 🔸 Сумма: 0.7268 | Описание: 0.3409 | Транскрипция: 0.3859 | ID: 1085 | Файл: https://s3.ritm.media/hackaton-itmo/1bc83532-22e6-4fc1-b628-03ed172c39e6.mp4
# 📝 Описание: В начале видео, на экране отображается текст: "Лучшие аниме для просмотра со своей парой" (Best anime to watch with your partner) с эмоджи в виде пары. Это предложение акцентирует внимание на совместном просмотре аниме.
#
# Далее, кадр раскрывает лицо п…
# 📜 Транскрипция: ПОДПИШИСЬ!…
#
# 🔸 Сумма: 0.7222 | Описание: 0.2975 | Транскрипция: 0.4247 | ID: 1311 | Файл: https://s3.ritm.media/hackaton-itmo/212662c6-b69f-472b-a9ad-401e844b7f3f.mp4
# 📝 Описание: В этом видео мы видим текст на экране, который написан по-русски. Текст включает несколько предложений и описывает воспоминания об одном человеке о том, как он думал, что его хвост — это штаны его мамы и что он является кошкой.
#
# Также привлекают вним…
# 📜 Транскрипция: а а…
#
# 🔸 Сумма: 0.7081 | Описание: 0.3099 | Транскрипция: 0.3982 | ID: 845 | Файл: https://s3.ritm.media/hackaton-itmo/15523e5c-3cd5-4a02-a1e3-4dbd014a0439.mp4
# 📝 Описание: В видео изначально показано сообщение на русском языке: "Когда весь такой радостный, но потом видишь 2 за контрольную". Это предупреждает о том, что подойдет к сюрпризу, который может испортить хорошее настроение. Затем появляется анимационная персон…
# 📜 Транскрипция: Скибиди Тойлет…
#
# 🔸 Сумма: 0.7070 | Описание: 0.3406 | Транскрипция: 0.3664 | ID: 1090 | Файл: https://s3.ritm.media/hackaton-itmo/1bf245d7-e645-423d-a34a-609b4153c78f.mp4
# 📝 Описание: В начале видео, на экране отсутствует какое-либо содержимое. Затем появляются анимационные персонажи: девушки с разными цветовыми волосами и одетые в одинаковый школьныйiform. Персонажи перемещаются, их лица показывают разные эмоции.
#
# Девушка с голуб…
# 📜 Транскрипция: Музыка…
#
# 🔸 Сумма: 0.7034 | Описание: 0.3370 | Транскрипция: 0.3664 | ID: 2875 | Файл: https://s3.ritm.media/hackaton-itmo/4901fc43-8370-4b6e-a09d-25c847d26a30.mp4
# 📝 Описание: The video begins with a title screen featuring the text "Аниматроники против скибиди вселенной часть 3" (Animatronics vs. Skibidi Universe Part 3). The scene transitions to an animated setting where two animatronic characters are present: one resembl…
# 📜 Транскрипция: Музыка…
